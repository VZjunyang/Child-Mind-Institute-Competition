# %%
import pandas as pd
import numpy as np 
from fancyimpute import SoftImpute
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv("all_participants_ts_extract_train.csv")
test = pd.read_csv("all_participants_ts_extract_test.csv")

# %%
covariates = pd.read_csv("../data/train.csv")

# %%
train["id"] = train["kid_id"]
train.drop("kid_id", axis=1, inplace=True)

# %%
imputed_columns = train.columns.drop(["id", "index"]).to_list()

# %%
joined_df = pd.merge(train, covariates, on="id")

# %%
shuffle_df = joined_df.sample(frac=1)

# %%
cat_c = ['Basic_Demos-Enroll_Season', 'CGAS-Season', 'Physical-Season', 'Fitness_Endurance-Season', 
        'FGC-Season', 'BIA-Season', 'PAQ_A-Season', 'PAQ_C-Season', 'SDS-Season', 'PreInt_EduHx-Season']
pciat = covariates.columns[covariates.columns.str.startswith('PCIAT-PCIAT')].tolist() + ['sii', "PCIAT-Season"]

joined_df_clean = pd.concat([joined_df, pd.get_dummies(joined_df[cat_c]).astype(int)], axis=1)
to_drop = ["id"] + cat_c + ["index"]
joined_df_clean = joined_df_clean.drop(to_drop, axis=1)
joined_df_clean = joined_df_clean.dropna(subset=pciat)
joined_df_clean = joined_df_clean.drop(pciat, axis=1)

# %%
soft_impute = SoftImpute(verbose=True)
scaler = StandardScaler()

shuffle_df_scaled = scaler.fit_transform(joined_df_clean)

val_data = shuffle_df_scaled[:200].copy()
shuffle_df_scaled[:200, :len(imputed_columns)-1] = np.nan

imputed_data = soft_impute.fit_transform(shuffle_df_scaled)

pred_val = imputed_data[:200]
# Out:
# [SoftImpute] Max Singular Value of X_init = 99.344095
# [SoftImpute] Iter 1: observed MAE=0.040265 rank=117
# [SoftImpute] Iter 2: observed MAE=0.040424 rank=117
# [SoftImpute] Iter 3: observed MAE=0.040493 rank=116
# [SoftImpute] Iter 4: observed MAE=0.040538 rank=116
# [SoftImpute] Iter 5: observed MAE=0.040576 rank=116
# [SoftImpute] Iter 6: observed MAE=0.040607 rank=116
# [SoftImpute] Iter 7: observed MAE=0.040633 rank=116
# [SoftImpute] Iter 8: observed MAE=0.040656 rank=116
# [SoftImpute] Iter 9: observed MAE=0.040676 rank=116
# [SoftImpute] Iter 10: observed MAE=0.040694 rank=116
# [SoftImpute] Iter 11: observed MAE=0.040710 rank=116
# [SoftImpute] Iter 12: observed MAE=0.040723 rank=116
# [SoftImpute] Iter 13: observed MAE=0.040735 rank=116
# [SoftImpute] Iter 14: observed MAE=0.040746 rank=116
# [SoftImpute] Iter 15: observed MAE=0.040755 rank=116
# [SoftImpute] Iter 16: observed MAE=0.040763 rank=116
# [SoftImpute] Iter 17: observed MAE=0.040770 rank=116
# [SoftImpute] Iter 18: observed MAE=0.040777 rank=116
# [SoftImpute] Iter 19: observed MAE=0.040779 rank=115
# [SoftImpute] Iter 20: observed MAE=0.040779 rank=115
# [SoftImpute] Iter 21: observed MAE=0.040779 rank=115
# [SoftImpute] Iter 22: observed MAE=0.040779 rank=115
# [SoftImpute] Iter 23: observed MAE=0.040778 rank=115
# [SoftImpute] Iter 24: observed MAE=0.040777 rank=115
# [SoftImpute] Iter 25: observed MAE=0.040776 rank=115
# [SoftImpute] Iter 26: observed MAE=0.040775 rank=115
# [SoftImpute] Iter 27: observed MAE=0.040774 rank=115
# [SoftImpute] Iter 28: observed MAE=0.040773 rank=115
# [SoftImpute] Iter 29: observed MAE=0.040771 rank=115
# [SoftImpute] Iter 30: observed MAE=0.040770 rank=115
# [SoftImpute] Iter 31: observed MAE=0.040769 rank=114
# [SoftImpute] Iter 32: observed MAE=0.040764 rank=114
# [SoftImpute] Iter 33: observed MAE=0.040761 rank=114
# [SoftImpute] Iter 34: observed MAE=0.040758 rank=114
# [SoftImpute] Iter 35: observed MAE=0.040755 rank=114
# [SoftImpute] Iter 36: observed MAE=0.040752 rank=114
# [SoftImpute] Iter 37: observed MAE=0.040749 rank=114
# [SoftImpute] Iter 38: observed MAE=0.040747 rank=114
# [SoftImpute] Iter 39: observed MAE=0.040744 rank=114
# [SoftImpute] Iter 40: observed MAE=0.040742 rank=114
# [SoftImpute] Iter 41: observed MAE=0.040740 rank=114
# [SoftImpute] Iter 42: observed MAE=0.040738 rank=114
# [SoftImpute] Iter 43: observed MAE=0.040736 rank=114
# [SoftImpute] Iter 44: observed MAE=0.040734 rank=114
# [SoftImpute] Iter 45: observed MAE=0.040733 rank=114
# [SoftImpute] Iter 46: observed MAE=0.040731 rank=114
# [SoftImpute] Iter 47: observed MAE=0.040730 rank=114
# [SoftImpute] Iter 48: observed MAE=0.040728 rank=114
# [SoftImpute] Iter 49: observed MAE=0.040727 rank=114
# [SoftImpute] Iter 50: observed MAE=0.040726 rank=114
# [SoftImpute] Iter 51: observed MAE=0.040725 rank=114
# [SoftImpute] Iter 52: observed MAE=0.040723 rank=114
# [SoftImpute] Iter 53: observed MAE=0.040722 rank=114
# [SoftImpute] Iter 54: observed MAE=0.040721 rank=114
# [SoftImpute] Iter 55: observed MAE=0.040720 rank=114
# [SoftImpute] Iter 56: observed MAE=0.040719 rank=114
# [SoftImpute] Iter 57: observed MAE=0.040718 rank=114
# [SoftImpute] Iter 58: observed MAE=0.040717 rank=114
# [SoftImpute] Iter 59: observed MAE=0.040717 rank=114
# [SoftImpute] Iter 60: observed MAE=0.040716 rank=114
# [SoftImpute] Iter 61: observed MAE=0.040715 rank=114
# [SoftImpute] Iter 62: observed MAE=0.040714 rank=114
# [SoftImpute] Iter 63: observed MAE=0.040714 rank=114
# [SoftImpute] Iter 64: observed MAE=0.040713 rank=114
# [SoftImpute] Iter 65: observed MAE=0.040712 rank=114
# [SoftImpute] Iter 66: observed MAE=0.040712 rank=114
# [SoftImpute] Iter 67: observed MAE=0.040711 rank=114
# [SoftImpute] Iter 68: observed MAE=0.040711 rank=114
# [SoftImpute] Iter 69: observed MAE=0.040710 rank=114
# [SoftImpute] Iter 70: observed MAE=0.040710 rank=114
# [SoftImpute] Iter 71: observed MAE=0.040709 rank=114
# [SoftImpute] Iter 72: observed MAE=0.040709 rank=114
# [SoftImpute] Iter 73: observed MAE=0.040709 rank=114
# [SoftImpute] Iter 74: observed MAE=0.040708 rank=114
# [SoftImpute] Iter 75: observed MAE=0.040708 rank=114
# [SoftImpute] Iter 76: observed MAE=0.040708 rank=114
# [SoftImpute] Iter 77: observed MAE=0.040707 rank=114
# [SoftImpute] Iter 78: observed MAE=0.040707 rank=114
# [SoftImpute] Iter 79: observed MAE=0.040707 rank=114
# [SoftImpute] Iter 80: observed MAE=0.040706 rank=114
# [SoftImpute] Iter 81: observed MAE=0.040706 rank=114
# [SoftImpute] Iter 82: observed MAE=0.040706 rank=114
# [SoftImpute] Iter 83: observed MAE=0.040706 rank=114
# [SoftImpute] Iter 84: observed MAE=0.040705 rank=114
# [SoftImpute] Iter 85: observed MAE=0.040705 rank=114
# [SoftImpute] Iter 86: observed MAE=0.040705 rank=114
# [SoftImpute] Iter 87: observed MAE=0.040705 rank=114
# [SoftImpute] Iter 88: observed MAE=0.040704 rank=114
# [SoftImpute] Iter 89: observed MAE=0.040704 rank=114
# [SoftImpute] Iter 90: observed MAE=0.040704 rank=114
# [SoftImpute] Iter 91: observed MAE=0.040704 rank=114
# [SoftImpute] Iter 92: observed MAE=0.040704 rank=114
# [SoftImpute] Iter 93: observed MAE=0.040704 rank=114
# [SoftImpute] Iter 94: observed MAE=0.040703 rank=114
# [SoftImpute] Iter 95: observed MAE=0.040703 rank=114
# [SoftImpute] Iter 96: observed MAE=0.040703 rank=114
# [SoftImpute] Iter 97: observed MAE=0.040703 rank=114
# [SoftImpute] Iter 98: observed MAE=0.040703 rank=114
# [SoftImpute] Iter 99: observed MAE=0.040703 rank=114
# [SoftImpute] Iter 100: observed MAE=0.040703 rank=114
# [SoftImpute] Stopped after iteration 100 for lambda=1.986882

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error

results = []
for i, feature in enumerate(imputed_columns):
    print(f"Feature: {feature}")
    print(f"RMSE: {mean_squared_error(val_data[:, i], pred_val[:, i], squared=False)}")
    print(f"R2: {r2_score(val_data[:, i], pred_val[:, i])}")
    print(f"MAPE: {mean_absolute_percentage_error(val_data[:, i], pred_val[:, i])}")
    print("")
    results.append(pd.DataFrame({ "RMSE": mean_squared_error(val_data[:, i], pred_val[:, i]),
                              "R2": r2_score(val_data[:, i], pred_val[:, i]),
                              "MAPE": mean_absolute_percentage_error(val_data[:, i], pred_val[:, i])},
                                index=[feature]
                              )
                    )
    
results_df = pd.concat(results)
# Out:
# Feature: enmo__sum_values
# RMSE: 1.0369886415253375
# R2: -0.018429021062556172
# MAPE: 1.1870669717698015
#
# Feature: enmo__median
# RMSE: 0.41873892804757207
# R2: -0.1897806832198219
# MAPE: 1.2261997425266202
#
# Feature: enmo__mean
# RMSE: 1.009169387451092
# R2: -0.0016603429727433117
# MAPE: 1.0245988731365367
#
# Feature: enmo__length
# RMSE: 0.7766782446373631
# R2: 0.12280951950575048
# MAPE: 1.1260150294286835
#
# Feature: enmo__standard_deviation
# RMSE: 1.0093339422195595
# R2: -0.007381160254596564
# MAPE: 1.0232578733124453
#
# Feature: enmo__variance
# RMSE: 1.0786399466517997
# R2: 0.01594975743990512
# MAPE: 1.0410115704522405
#
# Feature: enmo__root_mean_square
# RMSE: 1.0095887390642981
# R2: -0.00727264868580324
# MAPE: 1.0211166136725653
#
# Feature: enmo__maximum
# RMSE: 0.9832024378204703
# R2: -0.021127323002815057
# MAPE: 1.0572635147461917
#
# Feature: enmo__absolute_maximum
# RMSE: 0.9832024378204702
# R2: -0.021127323002814835
# MAPE: 1.0572635147461915
#
# Feature: enmo__minimum
# RMSE: 0.11806139055545037
# R2: -2.894911516487445e+32
# MAPE: 2.7100045206246044
#
# Feature: light__sum_values
# RMSE: 0.9470407976972235
# R2: 0.04982511980544957
# MAPE: 1.3195929552498114
#
# Feature: light__median
# RMSE: 1.1862604341363312
# R2: -0.02064830422585473
# MAPE: 1.9704747914759193
#
# Feature: light__mean
# RMSE: 0.944306036536627
# R2: 0.08544102446931556
# MAPE: 3.067646113089067
#
# Feature: light__length
# RMSE: 0.7766782446373629
# R2: 0.12280951950575081
# MAPE: 1.126015029428682
#
# Feature: light__standard_deviation
# RMSE: 0.9639548918949266
# R2: 0.09902963503185613
# MAPE: 1.166016758768056
#
# Feature: light__variance
# RMSE: 0.9081291975298474
# R2: 0.11222328126716408
# MAPE: 0.9623453529285504
#
# Feature: light__root_mean_square
# RMSE: 0.9559475293407019
# R2: 0.1044247119557461
# MAPE: 1.0437783193675017
#
# Feature: light__maximum
# RMSE: 0.9148609088452343
# R2: -0.044053474554548
# MAPE: 1.0277993850052825
#
# Feature: light__absolute_maximum
# RMSE: 0.9148846944986483
# R2: -0.044031923308077925
# MAPE: 1.0278021737867484
#
# Feature: light__minimum
# RMSE: 1.2009397016836116
# R2: -0.01030070748096712
# MAPE: 1.149107527830855
#
# Feature: hour__sum_values
# RMSE: 1.274051209965416
# R2: -0.003942900149825901
# MAPE: 1.9766823704958512
#
# Feature: hour__median
# RMSE: 1.241485262104852
# R2: 0.0032490932551292317
# MAPE: 1.070627112526964
#
# Feature: hour__mean
# RMSE: 1.170632901418952
# R2: 0.002781229630112181
# MAPE: 1.2480831394777534
#
# Feature: hour__length
# RMSE: 0.776678244637363
# R2: 0.12280951950575059
# MAPE: 1.1260150294286828
#
# Feature: hour__standard_deviation
# RMSE: 0.9948802936918951
# R2: 0.029585765841589562
# MAPE: 1.0512731416306698
#
# Feature: hour__variance
# RMSE: 1.0224829002782059
# R2: 0.004137407906389279
# MAPE: 1.0959830923056202
#
# Feature: hour__root_mean_square
# RMSE: 1.0267764531392933
# R2: 0.01531133208211266
# MAPE: 1.081094026052821
#
# Feature: hour__maximum
# RMSE: 0.995122445638531
# R2: 0.0170176438107853
# MAPE: 0.9825324942044381
#
# Feature: hour__absolute_maximum
# RMSE: 0.9956846622798501
# R2: 0.01643945635281774
# MAPE: 0.9827266418284042
#
# Feature: hour__minimum
# RMSE: 1.252574636687211
# R2: 0.011013673975570626
# MAPE: 1.0074633249365084
#
# Feature: weekday__sum_values
# RMSE: 1.2682002195559576
# R2: 0.02552783276659465
# MAPE: 1.3072909976073073
#
# Feature: weekday__median
# RMSE: 1.2372136079827492
# R2: 0.020886277355104288
# MAPE: 1.354724455144705
#
# Feature: weekday__mean
# RMSE: 1.1827810031993327
# R2: 0.027595440326053766
# MAPE: 1.0305171744803787
#
# Feature: weekday__length
# RMSE: 0.776678244637363
# R2: 0.12280951950575059
# MAPE: 1.1260150294286824
#
# Feature: weekday__standard_deviation
# RMSE: 0.7162112655942389
# R2: -0.050040710082424056
# MAPE: 0.9947657362731226
#
# Feature: weekday__variance
# RMSE: 0.6313778578618826
# R2: -0.0936023146123579
# MAPE: 1.2196669722114644
#
# Feature: weekday__root_mean_square
# RMSE: 0.9338769670871431
# R2: 0.006796656012673319
# MAPE: 1.30951005148137
#
# Feature: weekday__maximum
# RMSE: 0.9539647467738104
# R2: -0.0034680324962195197
# MAPE: 1.1376580996963745
#
# Feature: weekday__absolute_maximum
# RMSE: 0.9542492772604586
# R2: -0.003758572260540216
# MAPE: 1.1585982805806012
#
# Feature: weekday__minimum
# RMSE: 1.252513886910012
# R2: 0.019402168199535996
# MAPE: 1.0396804896538399
#
# Feature: relative_date_PCIAT__sum_values
# RMSE: 0.9249572584363204
# R2: 0.055113437061497184
# MAPE: 1.1066107622741124
#
# Feature: relative_date_PCIAT__median
# RMSE: 0.9325720038437223
# R2: 0.04613557648235478
# MAPE: 1.0736239053785241
#
# Feature: relative_date_PCIAT__mean
# RMSE: 0.9337910961808416
# R2: 0.04828660738740009
# MAPE: 1.0709450333257675
#
# Feature: relative_date_PCIAT__length
# RMSE: 0.776678244637363
# R2: 0.12280951950575059
# MAPE: 1.1260150294286826
#
# Feature: relative_date_PCIAT__standard_deviation
# RMSE: 0.5988472735919201
# R2: -0.010128630663733373
# MAPE: 1.3930725759495268
#
# Feature: relative_date_PCIAT__variance
# RMSE: 0.4424123609916155
# R2: -0.04892824743584745
# MAPE: 1.1045963019985394
#
# Feature: relative_date_PCIAT__root_mean_square
# RMSE: 0.8828047739036405
# R2: 0.06416272957336122
# MAPE: 1.172303221848329
#
# Feature: relative_date_PCIAT__maximum
# RMSE: 0.641752372155699
# R2: -0.02917450144281286
# MAPE: 1.4151881019574046
#
# Feature: relative_date_PCIAT__absolute_maximum
# RMSE: 0.6413542701632001
# R2: -0.027925941043386526
# MAPE: 1.5723986173243518
#
# Feature: relative_date_PCIAT__minimum
# RMSE: 0.9288614333829489
# R2: 0.04481532498013463
# MAPE: 1.1889980451605697
#
# Feature: peak_movement_hour
# RMSE: 0.974838737745318
# R2: 0.0010964957442302081
# MAPE: 1.0554183227991292
#
# Feature: peak_light_hour
# RMSE: 0.9172923322989895
# R2: 0.027851591739504244
# MAPE: 5.112353353596921
#
# Feature: avg_movement_day
# RMSE: 0.7726642123875426
# R2: 0.357946497045031
# MAPE: 1.7924024154717255
#
# Feature: avg_movement_night
# RMSE: 0.0
# R2: 1.0
# MAPE: 0.0
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Data/victor.zhuang/Code/MIT/env/lib64/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
results_df
# Out:
#                                              RMSE            R2      MAPE
# enmo__sum_values                         1.075345 -1.842902e-02  1.187067
# enmo__median                             0.175342 -1.897807e-01  1.226200
# enmo__mean                               1.018423 -1.660343e-03  1.024599
# enmo__length                             0.603229  1.228095e-01  1.126015
# enmo__standard_deviation                 1.018755 -7.381160e-03  1.023258
# enmo__variance                           1.163464  1.594976e-02  1.041012
# enmo__root_mean_square                   1.019269 -7.272649e-03  1.021117
# enmo__maximum                            0.966687 -2.112732e-02  1.057264
# enmo__absolute_maximum                   0.966687 -2.112732e-02  1.057264
# enmo__minimum                            0.013938 -2.894912e+32  2.710005
# light__sum_values                        0.896886  4.982512e-02  1.319593
# light__median                            1.407214 -2.064830e-02  1.970475
# light__mean                              0.891714  8.544102e-02  3.067646
# light__length                            0.603229  1.228095e-01  1.126015
# light__standard_deviation                0.929209  9.902964e-02  1.166017
# light__variance                          0.824699  1.122233e-01  0.962345
# light__root_mean_square                  0.913836  1.044247e-01  1.043778
# light__maximum                           0.836970 -4.405347e-02  1.027799
# light__absolute_maximum                  0.837014 -4.403192e-02  1.027802
# light__minimum                           1.442256 -1.030071e-02  1.149108
# hour__sum_values                         1.623206 -3.942900e-03  1.976682
# hour__median                             1.541286  3.249093e-03  1.070627
# hour__mean                               1.370381  2.781230e-03  1.248083
# hour__length                             0.603229  1.228095e-01  1.126015
# hour__standard_deviation                 0.989787  2.958577e-02  1.051273
# hour__variance                           1.045471  4.137408e-03  1.095983
# hour__root_mean_square                   1.054270  1.531133e-02  1.081094
# hour__maximum                            0.990269  1.701764e-02  0.982532
# hour__absolute_maximum                   0.991388  1.643946e-02  0.982727
# hour__minimum                            1.568943  1.101367e-02  1.007463
# weekday__sum_values                      1.608332  2.552783e-02  1.307291
# weekday__median                          1.530698  2.088628e-02  1.354724
# weekday__mean                            1.398971  2.759544e-02  1.030517
# weekday__length                          0.603229  1.228095e-01  1.126015
# weekday__standard_deviation              0.512959 -5.004071e-02  0.994766
# weekday__variance                        0.398638 -9.360231e-02  1.219667
# weekday__root_mean_square                0.872126  6.796656e-03  1.309510
# weekday__maximum                         0.910049 -3.468032e-03  1.137658
# weekday__absolute_maximum                0.910592 -3.758572e-03  1.158598
# weekday__minimum                         1.568791  1.940217e-02  1.039680
# relative_date_PCIAT__sum_values          0.855546  5.511344e-02  1.106611
# relative_date_PCIAT__median              0.869691  4.613558e-02  1.073624
# relative_date_PCIAT__mean                0.871966  4.828661e-02  1.070945
# relative_date_PCIAT__length              0.603229  1.228095e-01  1.126015
# relative_date_PCIAT__standard_deviation  0.358618 -1.012863e-02  1.393073
# relative_date_PCIAT__variance            0.195729 -4.892825e-02  1.104596
# relative_date_PCIAT__root_mean_square    0.779344  6.416273e-02  1.172303
# relative_date_PCIAT__maximum             0.411846 -2.917450e-02  1.415188
# relative_date_PCIAT__absolute_maximum    0.411335 -2.792594e-02  1.572399
# relative_date_PCIAT__minimum             0.862784  4.481532e-02  1.188998
# peak_movement_hour                       0.950311  1.096496e-03  1.055418
# peak_light_hour                          0.841425  2.785159e-02  5.112353
# avg_movement_day                         0.597010  3.579465e-01  1.792402
# avg_movement_night                       0.000000  1.000000e+00  0.000000

# %%
print("Top 5 features with lowest RMSE")

display(results_df.sort_values("RMSE").head(5))

print("Top 5 features with highest R2")

display(results_df.sort_values("R2", ascending=False).head(5))

print("Top 5 features with lowest MAPE")

display(results_df.sort_values("MAPE").head(5))
# Out:
# Top 5 features with lowest RMSE
#                                              RMSE            R2      MAPE
# avg_movement_night                       0.000000  1.000000e+00  0.000000
# enmo__minimum                            0.013938 -2.894912e+32  2.710005
# enmo__median                             0.175342 -1.897807e-01  1.226200
# relative_date_PCIAT__variance            0.195729 -4.892825e-02  1.104596
# relative_date_PCIAT__standard_deviation  0.358618 -1.012863e-02  1.393073
# Top 5 features with highest R2
#                                  RMSE        R2      MAPE
# avg_movement_night           0.000000  1.000000  0.000000
# avg_movement_day             0.597010  0.357946  1.792402
# light__length                0.603229  0.122810  1.126015
# weekday__length              0.603229  0.122810  1.126015
# relative_date_PCIAT__length  0.603229  0.122810  1.126015
# Top 5 features with lowest MAPE
#                                  RMSE        R2      MAPE
# avg_movement_night           0.000000  1.000000  0.000000
# light__variance              0.824699  0.112223  0.962345
# hour__maximum                0.990269  0.017018  0.982532
# hour__absolute_maximum       0.991388  0.016439  0.982727
# weekday__standard_deviation  0.512959 -0.050041  0.994766
