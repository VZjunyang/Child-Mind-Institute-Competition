# %%
using DataFrames
using CSV
using DataFrames
using StatsBase

# Load the CSV files into data frames
train = CSV.read("../../data/train.csv", DataFrame)
test = CSV.read("../../data/test.csv", DataFrame)
data_dict = CSV.read("../../data/data_dictionary.csv", DataFrame)

# Display the data
first(train, 5)
first(test, 5)
first(data_dict, 5)
# Out:
# 5×6 DataFrame
#  Row │ Instrument                         Field                      Descripti ⋯
#      │ String                             String                     String    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Identifier                         id                         Participa ⋯
#    2 │ Demographics                       Basic_Demos-Enroll_Season  Season of
#    3 │ Demographics                       Basic_Demos-Age            Age of pa
#    4 │ Demographics                       Basic_Demos-Sex            Sex of pa
#    5 │ Children's Global Assessment Sca…  CGAS-Season                Season of ⋯
#                                                                4 columns omitted

# %%
# Specify the categorical columns
cat_c = ["Basic_Demos-Enroll_Season", "CGAS-Season", "Physical-Season", "Fitness_Endurance-Season", 
           "FGC-Season", "BIA-Season", "PAQ_A-Season", "PAQ_C-Season", "SDS-Season", "PreInt_EduHx-Season",
            "Basic_Demos-Sex", "FGC-FGC_CU_Zone", "FGC-FGC_GSND_Zone", "FGC-FGC_GSD_Zone",
           "FGC-FGC_PU_Zone", "FGC-FGC_SRL_Zone", "FGC-FGC_SRR_Zone", "FGC-FGC_TL_Zone", "BIA-BIA_Activity_Level_num",
           "BIA-BIA_Frame_num"]

id_col = ["id"]

pciat = filter(name -> startswith(name, "PCIAT-PCIAT"), names(train))
append!(pciat, ["sii", "PCIAT-Season"])

columns_float = setdiff(names(train), cat_c ∪ pciat ∪ id_col)

# Filter the numeric columns and convert them to numeric types
train_filtered_float = train[:, columns_float]
train_filtered_cat = train[:, cat_c]

for col in names(train_filtered_float)
    train_filtered_float[!, col] = map(x -> 
        try 
            parse(Float64, string(x)) 
        catch 
            missing 
        end, train_filtered_float[!, col])
end

# %%
function calculate_mode(column)
    nonmissing_values = skipmissing(column)
    return mode(nonmissing_values)
end

for col in names(train_filtered_cat)
    column = train_filtered_cat[!, col]
    mode_val = calculate_mode(column)
    train_filtered_cat[!, col] = map(x -> ismissing(x) ? mode_val : x, column)
end

# %%
lnr = IAI.OptKNNImputationLearner(method = "opt_knn", random_seed=12)
# Out:
# Unfitted OptKNNImputationLearner:
#   random_seed: 12

# %%
IAI.fit!(lnr, train_filtered_float)
# Out:
# [ Warning: This copy of Interpretable AI software is for academic purposes only and not for commercial use.
# ┌ Warning: Interpretable AI license expires soon: 2024-12-31T00:00:00. If you need to renew, please send us the following machine ID:
# └ bed1c049b33cf139e0b18189fbbed293e73573685741fed0de8b4df77326d308
# [ Warning: Imputed value for X[35, 38] less than machine epsilon, has been rounded to zero.
# Fitted OptKNNImputationLearner

# %%
completed_data = IAI.transform(lnr, train_filtered_float)
# Out:
# 3960×38 DataFrame
#   Row │ Basic_Demos-Age  CGAS-CGAS_Score  Physical-BMI  Physical-Height  Physi ⋯
#       │ Float64?         Float64?         Float64?      Float64?         Float ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │             5.0          51.0          16.8773          46.0           ⋯
#     2 │             9.0          69.6367       14.0356          48.0
#     3 │            10.0          71.0          16.6487          56.5
#     4 │             9.0          71.0          18.2923          56.0
#     5 │            18.0          59.6789       20.7594          64.3865        ⋯
#     6 │            13.0          50.0          22.28            59.5
#     7 │            10.0          69.9724       19.6608          55.0
#     8 │            10.0          61.2465       16.8613          59.25
#     9 │            15.0          66.5426       20.6969          65.4208        ⋯
#    10 │            19.0          61.1888       22.0716          68.0366
#    11 │            11.0          65.6446       19.8026          58.9344
#   ⋮   │        ⋮                ⋮              ⋮               ⋮               ⋱
#  3951 │             9.0          63.0248       20.2005          52.5
#  3952 │             7.0          64.8883       14.7688          47.5           ⋯
#  3953 │            15.0          40.0          26.3647          70.5
#  3954 │             8.0          60.3856       17.1398          52.5
#  3955 │             7.0          64.9734       13.927           48.5
#  3956 │            13.0          60.0          16.3625          59.5           ⋯
#  3957 │            10.0          62.7351       18.7647          53.5
#  3958 │            11.0          68.0          21.4415          60.0
#  3959 │            13.0          70.0          12.2359          70.7
#  3960 │            11.0          66.7181       18.6907          54.6248        ⋯
#                                                 34 columns and 3939 rows omitted

# %%
append!(cat_c, pciat, id_col)
# Out:
# 44-element Vector{String}:
#  "Basic_Demos-Enroll_Season"
#  "CGAS-Season"
#  "Physical-Season"
#  "Fitness_Endurance-Season"
#  "FGC-Season"
#  "BIA-Season"
#  "PAQ_A-Season"
#  "PAQ_C-Season"
#  "SDS-Season"
#  "PreInt_EduHx-Season"
#  "Basic_Demos-Sex"
#  "FGC-FGC_CU_Zone"
#  "FGC-FGC_GSND_Zone"
#  ⋮
#  "PCIAT-PCIAT_13"
#  "PCIAT-PCIAT_14"
#  "PCIAT-PCIAT_15"
#  "PCIAT-PCIAT_16"
#  "PCIAT-PCIAT_17"
#  "PCIAT-PCIAT_18"
#  "PCIAT-PCIAT_19"
#  "PCIAT-PCIAT_20"
#  "PCIAT-PCIAT_Total"
#  "sii"
#  "PCIAT-Season"
#  "id"

# %%
# Combine the imputed data with the removed columns
train_final = hcat(completed_data, train[:, cat_c])
# Reorder columns to match the original dataset order
train_final = train_final[:, names(train)]
# Out:
# 3960×82 DataFrame
#   Row │ id        Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  ⋯
#       │ String15  String7                    Float64?         Int64            ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ 00008ff9  Fall                                   5.0                0  ⋯
#     2 │ 000fd460  Summer                                 9.0                0
#     3 │ 00105258  Summer                                10.0                1
#     4 │ 00115b9f  Winter                                 9.0                0
#     5 │ 0016bb22  Spring                                18.0                1  ⋯
#     6 │ 001f3379  Spring                                13.0                1
#     7 │ 0038ba98  Fall                                  10.0                0
#     8 │ 0068a485  Fall                                  10.0                1
#     9 │ 0069fbed  Summer                                15.0                0  ⋯
#    10 │ 0083e397  Summer                                19.0                1
#    11 │ 0087dd65  Spring                                11.0                1
#   ⋮   │    ⋮                  ⋮                     ⋮                ⋮         ⋱
#  3951 │ ff0ab367  Spring                                 9.0                0
#  3952 │ ff18b749  Spring                                 7.0                0  ⋯
#  3953 │ ff60112d  Summer                                15.0                0
#  3954 │ ff6c2bb8  Fall                                   8.0                0
#  3955 │ ff759544  Summer                                 7.0                1
#  3956 │ ff8a2de4  Fall                                  13.0                0  ⋯
#  3957 │ ffa9794a  Winter                                10.0                0
#  3958 │ ffcd4dbd  Fall                                  11.0                0
#  3959 │ ffed1dd5  Spring                                13.0                0
#  3960 │ ffef538e  Spring                                11.0                0  ⋯
#                                                 78 columns and 3939 rows omitted

# %%
# Save the final DataFrame to a CSV file
CSV.write("../training_sets/imputed_train_optimal_knn.csv", train_final)
# Out:
# "../imputed_train_optimal_knn.csv"
