# %%
using DataFrames
using CSV
using DataFrames

# Load the CSV files into data frames
train = CSV.read("../../../../data/train.csv", DataFrame)
test = CSV.read("../../../../data/test.csv", DataFrame)
data_dict = CSV.read("../../../../data/data_dictionary.csv", DataFrame)

# Display the data
first(train, 5)
first(test, 5)
first(data_dict, 5)
# Out:
# 5×6 DataFrame
#  Row │ Instrument                         Field                      Descripti ⋯
#      │ String                             String                     String    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Identifier                         id                         Participa ⋯
#    2 │ Demographics                       Basic_Demos-Enroll_Season  Season of
#    3 │ Demographics                       Basic_Demos-Age            Age of pa
#    4 │ Demographics                       Basic_Demos-Sex            Sex of pa
#    5 │ Children's Global Assessment Sca…  CGAS-Season                Season of ⋯
#                                                                4 columns omitted

# %%
# Specify the categorical columns
cat_c = [
    "Basic_Demos-Enroll_Season", "CGAS-Season", "Physical-Season", "Fitness_Endurance-Season", 
    "FGC-Season", "BIA-Season", "PAQ_A-Season", "PAQ_C-Season", "SDS-Season", 
    "PreInt_EduHx-Season", "id"
]

# Identify columns that start with "PCIAT.PCIAT" and other specified columns
pciat = filter(name -> startswith(name, "PCIAT-PCIAT"), names(train))
append!(pciat, ["sii", "PCIAT-Season"])

# Get numeric columns to filter
columns_float = setdiff(names(train), cat_c ∪ pciat)

# Filter the numeric columns and convert them to numeric types
train_filtered = train[:, columns_float]
for col in names(train_filtered)
    train_filtered[!, col] = map(x -> 
        try 
            parse(Float64, string(x)) 
        catch 
            missing 
        end, train_filtered[!, col])
end

# %%
lnr = IAI.OptKNNImputationLearner(method = "opt_knn", random_seed=12)
# Out:
# Unfitted OptKNNImputationLearner:
#   random_seed: 12

# %%
IAI.fit!(lnr, train_filtered)
# Out:
# [ Warning: This copy of Interpretable AI software is for academic purposes only and not for commercial use.
# ┌ Warning: Interpretable AI license expires soon: 2024-12-31T00:00:00. If you need to renew, please send us the following machine ID:
# └ bed1c049b33cf139e0b18189fbbed293e73573685741fed0de8b4df77326d308
# [ Warning: Imputed value for X[9, 15] less than machine epsilon, has been rounded to zero.
# Fitted OptKNNImputationLearner

# %%
completed_data = IAI.transform(lnr, train_filtered)
# Out:
# 3960×48 DataFrame
#   Row │ Basic_Demos-Age  Basic_Demos-Sex  CGAS-CGAS_Score  Physical-BMI  Physi ⋯
#       │ Float64?         Float64?         Float64?         Float64?      Float ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │             5.0              0.0          51.0          16.8773        ⋯
#     2 │             9.0              0.0          56.2841       14.0356
#     3 │            10.0              1.0          71.0          16.6487
#     4 │             9.0              0.0          71.0          18.2923
#     5 │            18.0              1.0          73.9669       23.438         ⋯
#     6 │            13.0              1.0          50.0          22.28
#     7 │            10.0              0.0          59.8766       19.6608
#     8 │            10.0              1.0          61.426        16.8613
#     9 │            15.0              0.0          64.0644       17.9962        ⋯
#    10 │            19.0              1.0          64.2119       32.3067
#    11 │            11.0              1.0          70.6742       24.043
#   ⋮   │        ⋮                ⋮                ⋮              ⋮              ⋱
#  3951 │             9.0              0.0          67.3457       20.2005
#  3952 │             7.0              0.0          69.5029       14.7688        ⋯
#  3953 │            15.0              0.0          40.0          26.3647
#  3954 │             8.0              0.0          64.3648       17.1398
#  3955 │             7.0              1.0          67.9451       13.927
#  3956 │            13.0              0.0          60.0          16.3625        ⋯
#  3957 │            10.0              0.0          63.4486       18.7647
#  3958 │            11.0              0.0          68.0          21.4415
#  3959 │            13.0              0.0          70.0          12.2359
#  3960 │            11.0              0.0          69.0971       20.0913        ⋯
#                                                 44 columns and 3939 rows omitted

# %%
append!(cat_c, pciat)
# Out:
# 34-element Vector{String}:
#  "Basic_Demos-Enroll_Season"
#  "CGAS-Season"
#  "Physical-Season"
#  "Fitness_Endurance-Season"
#  "FGC-Season"
#  "BIA-Season"
#  "PAQ_A-Season"
#  "PAQ_C-Season"
#  "SDS-Season"
#  "PreInt_EduHx-Season"
#  "id"
#  "PCIAT-PCIAT_01"
#  "PCIAT-PCIAT_02"
#  ⋮
#  "PCIAT-PCIAT_12"
#  "PCIAT-PCIAT_13"
#  "PCIAT-PCIAT_14"
#  "PCIAT-PCIAT_15"
#  "PCIAT-PCIAT_16"
#  "PCIAT-PCIAT_17"
#  "PCIAT-PCIAT_18"
#  "PCIAT-PCIAT_19"
#  "PCIAT-PCIAT_20"
#  "PCIAT-PCIAT_Total"
#  "sii"
#  "PCIAT-Season"

# %%
size(cat_c)
# Out:
# (34,)

# %%
# Combine the imputed data with the removed columns
train_final = hcat(completed_data, train[:, cat_c])

# Reorder columns to match the original dataset order
train_final = train_final[:, names(train)]
# Out:
# 3960×82 DataFrame
#   Row │ id        Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  ⋯
#       │ String15  String7                    Float64?         Float64?         ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ 00008ff9  Fall                                   5.0              0.0  ⋯
#     2 │ 000fd460  Summer                                 9.0              0.0
#     3 │ 00105258  Summer                                10.0              1.0
#     4 │ 00115b9f  Winter                                 9.0              0.0
#     5 │ 0016bb22  Spring                                18.0              1.0  ⋯
#     6 │ 001f3379  Spring                                13.0              1.0
#     7 │ 0038ba98  Fall                                  10.0              0.0
#     8 │ 0068a485  Fall                                  10.0              1.0
#     9 │ 0069fbed  Summer                                15.0              0.0  ⋯
#    10 │ 0083e397  Summer                                19.0              1.0
#    11 │ 0087dd65  Spring                                11.0              1.0
#   ⋮   │    ⋮                  ⋮                     ⋮                ⋮         ⋱
#  3951 │ ff0ab367  Spring                                 9.0              0.0
#  3952 │ ff18b749  Spring                                 7.0              0.0  ⋯
#  3953 │ ff60112d  Summer                                15.0              0.0
#  3954 │ ff6c2bb8  Fall                                   8.0              0.0
#  3955 │ ff759544  Summer                                 7.0              1.0
#  3956 │ ff8a2de4  Fall                                  13.0              0.0  ⋯
#  3957 │ ffa9794a  Winter                                10.0              0.0
#  3958 │ ffcd4dbd  Fall                                  11.0              0.0
#  3959 │ ffed1dd5  Spring                                13.0              0.0
#  3960 │ ffef538e  Spring                                11.0              0.0  ⋯
#                                                 78 columns and 3939 rows omitted

# %%
# Save the final DataFrame to a CSV file
CSV.write("optimal_imputed_train.csv", train_final)
# Out:
# "optimal_imputed_train.csv"
